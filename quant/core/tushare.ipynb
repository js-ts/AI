# %%
import tushare as ts
import time
import numpy as np
import pandas as pd

# %%
pro = ts.pro_api(token='14544f66a3a8c9fad2c7d81df3faf20165b248745ce5e8cf994718cb')

# %%
[n for n in dir(pro) if not n.startswith('_')]
# Out:
# ['query']

# %% [markdown]
# # BASIC

# %%
# stock_basic

# %%
data = pro.query('stock_basic', 
                 exchange='', 
                 list_status='L', 
                 fields='ts_code,symbol,name,area,industry,market,list_date,list_status')

# %%
data.drop_duplicates().reset_index().loc[:10, :]
# Out:
#     index    ts_code  symbol  name area industry market list_status list_date
# 0       0  000001.SZ  000001  平安银行   深圳       银行     主板           L  19910403
# 1       1  000002.SZ  000002   万科A   深圳     全国地产     主板           L  19910129
# 2       2  000004.SZ  000004  国华网安   深圳      互联网     主板           L  19910114
# 3       3  000005.SZ  000005  世纪星源   深圳     环境保护     主板           L  19901210
# 4       4  000006.SZ  000006  深振业A   深圳     区域地产     主板           L  19920427
# 5       5  000007.SZ  000007   全新好   深圳     酒店餐饮     主板           L  19920413
# 6       6  000008.SZ  000008  神州高铁   北京     运输设备     主板           L  19920507
# 7       7  000009.SZ  000009  中国宝安   深圳      综合类     主板           L  19910625
# 8       8  000010.SZ  000010  美丽生态   深圳     建筑工程     主板           L  19951027
# 9       9  000011.SZ  000011  深物业A   深圳     区域地产     主板           L  19920330
# 10     10  000012.SZ  000012   南玻A   深圳       玻璃     主板           L  19920228

# %%
# top10_holders
# top10_floatholders
#

# %%
topten = pro.query('top10_floatholders', ts_code='300014.SZ').loc[:30, :]

# %%
topten
# Out:
#       ts_code  ann_date  end_date  \
# 0   300014.SZ  20201029  20200930
# 1   300014.SZ  20201029  20200930
# 2   300014.SZ  20201029  20200930
# 3   300014.SZ  20201029  20200930
# 4   300014.SZ  20201029  20200930
# 5   300014.SZ  20201029  20200930
# 6   300014.SZ  20201029  20200930
# 7   300014.SZ  20201029  20200930
# 8   300014.SZ  20201029  20200930
# 9   300014.SZ  20201029  20200930
# 10  300014.SZ  20201029  20200930
# 11  300014.SZ  20201029  20200930
# 12  300014.SZ  20200825  20200630
# 13  300014.SZ  20200825  20200630
# 14  300014.SZ  20200825  20200630
# 15  300014.SZ  20200825  20200630
# 16  300014.SZ  20200825  20200630
# 17  300014.SZ  20200825  20200630
# 18  300014.SZ  20200825  20200630
# 19  300014.SZ  20200825  20200630
# 20  300014.SZ  20200825  20200630
# 21  300014.SZ  20200825  20200630
# 22  300014.SZ  20200825  20200630
# 23  300014.SZ  20200425  20200331
# 24  300014.SZ  20200425  20200331
# 25  300014.SZ  20200425  20200331
# 26  300014.SZ  20200425  20200331
# 27  300014.SZ  20200425  20200331
# 28  300014.SZ  20200425  20200331
# 29  300014.SZ  20200425  20200331
# 30  300014.SZ  20200425  20200331
#
#                                          holder_name  hold_amount
# 0                                         西藏亿纬控股有限公司  607407917.0
# 1          汇安基金-华能信托·博远惠诚集合资金信托计划-汇安基金-汇鑫32号单一资产管理计划   68606307.0
# 2                                    香港中央结算有限公司(陆股通)   47850648.0
# 3                       中国建设银行股份有限公司-广发科技先锋混合型证券投资基金   36406666.0
# 4                       中国工商银行股份有限公司-广发双擎升级混合型证券投资基金   24851110.0
# 5                                                骆锦红   24196583.0
# 6                上海浦东发展银行股份有限公司-广发小盘成长混合型证券投资基金(LOF
# 25     28  300014.SZ  20200425  20200331
# 26     29  300014.SZ  20200425  20200331
# 27     30  300014.SZ  20200425  20200331
#
#                                          holder_name  hold_amount
# 0                                         西藏亿纬控股有限公司  607407917.0
# 1          汇安基金-华能信托·博远惠诚集合资金信托计划-汇安基金-汇鑫32号单一资产管理计划   68606307.0
# 2                                    香港中央结算有限公司(陆股通)   47850648.0
# 3                       中国建设银行股份有限公司-广发科技先锋混合型证券投资基金   36406666.0
# 4                       中国工商银行股份有限公司-广发双擎升级混合型证券投资基金   24851110.0
# 5                                                骆锦红   24196583.0
# 6                上海浦东发展银行股份有限公司-广发小盘成长混合型证券投资基金(LOF)   21085671.0
# 7                   中国工商银行股份有限公司-广发创新升级灵活配置混合型证券投资基金   16433126.0
# 8   北信瑞丰资管-非凡资产管理翠竹13W理财产品周四公享01款-上海北信民生凤凰9号单一资产管理计划   15421803.0
# 9                        中国银行股份有限公司-易方达均衡成长股票型证券投资基金   13768678.0
# 10                                        西藏亿纬控股有限公司  607407917.0
# 11         汇安基金-华能信托·博远惠诚集合资金信托计划-汇安基金-汇鑫32号单一资产管理计划   87436697.0
# 12                                   香港中央结算有限公司(陆股通)   56393388.0
# 13                      中国建设银行股份有限公司-广发科技先锋混合型证券投资基金   36406666.0
# 14                      中国工商银行股份有限公司-广发双擎升级混合型证券投资基金   24851110.0
# 15                                               骆锦红   24196583.0
# 16  北信瑞丰资管-非凡资产管理翠竹13W理财产品周四公享01款-上海北信民生凤凰9号单一资产管理计划   23293794.0
# 17               上海浦东发展银行股份有限公司-广发小盘成长混合型证券投资基金(LOF)   21085671.0
# 18                  中国工商银行股份有限公司-广发创新升级灵活配置混合型证券投资基金   16433126.0
# 19                       中国银行股份有限公司-易方达均衡成长股票型证券投资基金   13991121.0
# 20                                        西藏亿纬控股有限公司  319541422.0
# 21                                   香港中央结算有限公司(陆股通)   19578529.0
# 22                      中国建设银行股份有限公司-广发科技先锋混合型证券投资基金   18413181.0
# 23                                               骆锦红   12729189.0
# 24                      中国工商银行股份有限公司-广发双擎升级混合型证券投资基金   11073520.0
# 25                  中国建设银行股份有限公司-交银施罗德经济新动力混合型证券投资基金   10305580.0
# 26                中国银行股份有限公司-华夏中证新能源汽车交易型开放式指数证券投资基金    9396842.0
# 27               上海浦东发展银行股份有限公司-广发小盘成长混合型证券投资基金(LOF)    8911520.0

# %%
topten.to_csv('./toptens.csv', sep='\t')

# %%
# Get topten data

# %%
stock_basic = pro.query('stock_basic', 
             exchange='', 
             list_status='L', 
             fields='ts_code,symbol,name,area,industry,market,list_date,list_status')

stock_basic.to_csv('stock_basic.csv', sep='\t')

# %%
def save_topten_data(filename, N=40):
    '''10 * 4000 / 60 / 60 = 11h
    '''
    data = pro.query('stock_basic', 
                 exchange='', 
                 list_status='L', 
                 fields='ts_code,symbol,name,area,industry,market,list_date,list_status')

    toptens = []
    for i, code in enumerate(data.ts_code):
        topten = pro.query('top10_floatholders', ts_code=code).loc[:N+20, :].drop_duplicates().loc[:N, :]
        toptens.append(topten)
        
        time.sleep(6.1)
        
    toptens = pd.concat(toptens)
    toptens.to_csv(filename, sep='\t')
    
save_topten_data('./toptens.csv')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Miniconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Miniconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Miniconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~\Miniconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~\Miniconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ~\Miniconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# ~\Miniconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\Miniconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\Miniconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~\Miniconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002544FF942C8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Miniconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Miniconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002544FF942C8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-35-7bec210a76e0> in <module>
#      18
#      19
# ---> 20 save_topten_data('./toptens.csv')
#
# <ipython-input-35-7bec210a76e0> in save_topten_data(filename, N)
#       9     tostens = []
#      10     for i, code in enumerate(data.ts_code):
# ---> 11         topten = pro.query('top10_floatholders', ts_code=code).loc[:N+20, :].drop_duplicates().loc[:N, :]
#      12         tostens.append(topten)
#      13
#
# ~\Miniconda3\lib\site-packages\tushare\pro\client.py in query(self, api_name, fields, **kwargs)
#      38         }
#      39
# ---> 40         res = requests.post(self.__http_url, json=req_params, timeout=self.__timeout, headers={'Connection':'close'})
#      41         if res:
#      42             result = json.loads(res.text)
#
# ~\Miniconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~\Miniconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Miniconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Miniconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Miniconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='api.waditu.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002544FF942C8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
# analysis-01

# %%
names = ['进化论']

# %%
final_code = []

for code in data.ts_code:
    # print(type(code), code)
    topten = pro.query('top10_floatholders', ts_code=code).loc[:30, :].drop_duplicates().loc[:10, :]
    
    time.sleep(10) # 抱歉，您每分钟最多访问该接口10次，
    
#     for holder in topten.holder_name:
#         if names[0] in holder:
#             # print(code)
#             final_code.append(code)
#             break

# %%
for n in topten.holder_name:
    print(n)
# Out:
# 中国建设银行股份有限公司-华安聚优精选混合型证券投资基金
# 中国平安保险(集团)股份有限公司-集团本级-自有资金
# 香港中央结算有限公司(陆股通)
# 中国平安人寿保险股份有限公司-自有资金
# 中国平安人寿保险股份有限公司-传统-普通保险产品
# 中国证券金融股份有限公司
# 中央汇金资产管理有限责任公司
# 深圳中电投资股份有限公司
# 河南鸿宝企业管理有限公司
# 全国社保基金一一七组合

# %%
np.concatenate([np.array(topten), np.array(topten)], axis=0).shape
# Out:
# (62, 5)

# %%
np.array(topten).shape
# Out:
# (31, 5)

# %%
np.save('test.npy', np.array(topten))

# %%
pd.concat([topten, topten])
# Out:
#       ts_code  ann_date  end_date                                holder_name  \
# 0   300014.SZ  20201029  20200930                                 西藏亿纬控股有限公司
# 1   300014.SZ  20201029  20200930  汇安基金-华能信托·博远惠诚集合资金信托计划-汇安基金-汇鑫32号单一资产管理计划
# 2   300014.SZ  20201029  20200930                            香港中央结算有限公司(陆股通)
# 3   300014.SZ  20201029  20200930               中国建设银行股份有限公司-广发科技先锋混合型证券投资基金
# 4   300014.SZ  20201029  20200930               中国工商银行股份有限公司-广发双擎升级混合型证券投资基金
# ..        ...       ...       ...                                        ...
# 26  300014.SZ  20200425  20200331                                        骆锦红
# 27  300014.SZ  20200425  20200331               中国工商银行股份有限公司-广发双擎升级混合型证券投资基金
# 28  300014.SZ  20200425  20200331           中国建设银行股份有限公司-交银施罗德经济新动力混合型证券投资基金
# 29  300014.SZ  20200425  20200331         中国银行股份有限公司-华夏中证新能源汽车交易型开放式指数证券投资基金
# 30  300014.SZ  20200425  20200331        上海浦东发展银行股份有限公司-广发小盘成长混合型证券投资基金(LOF)
#
#     hold_amount
# 0   607407917.0
# 1    68606307.0
# 2    47850648.0
# 3    36406666.0
# 4    24851110.0
# ..          ...
# 26   12729189.0
# 27   11073520.0
# 28   10305580.0
# 29    9396842.0
# 30    8911520.0
#
# [62 rows x 5 columns]
